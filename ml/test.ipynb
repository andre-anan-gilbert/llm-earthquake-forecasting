# %%
import numpy as np
import pandas as pd
import catboost as cb
from datetime import datetime, timedelta

# %%
model = cb.CatBoostRegressor()
model = model.load_model('forecasting_model')

# %%
df = pd.read_csv('https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&limit=20000&eventtype=earthquake')
df.time = pd.to_datetime(df.time)
df.time = df.time.dt.tz_localize(None)
df = df.sort_values("time")
df = df.set_index('time')
df.head()
# Out:
#                          latitude   longitude  depth   mag magType   nst  \
# time
# 2024-06-11 06:15:24.120   38.4890 -112.900333   3.05  0.91      md  11.0
# 2024-06-11 06:17:43.805   34.9500   25.142500  10.00  4.40      mb  55.0
# 2024-06-11 06:19:01.110   51.9215  178.493833   6.32  0.33      ml   4.0
# 2024-06-11 06:27:08.787   39.0263   72.069500  10.00  4.10      mb  31.0
# 2024-06-11 06:36:28.820   38.4950 -112.891000   3.01  0.91      md  17.0
#
#                            gap      dmin   rms net  ...  \
# time                                                ...
# 2024-06-11 06:15:24.120   98.0  0.008125  0.09  uu  ...
# 2024-06-11 06:17:43.805   98.0  0.396000  1.09  us  ...
# 2024-06-11 06:19:01.110  299.0  0.028950  0.07  av  ...
# 2024-06-11 06:27:08.787  136.0  0.497000  0.78  us  ...
# 2024-06-11 06:36:28.820   57.0  0.007406  0.17  uu  ...
#
#                                           updated  \
# time
# 2024-06-11 06:15:24.120  2024-06-13T20:28:19.060Z
# 2024-06-11 06:17:43.805  2024-06-28T12:12:51.462Z
# 2024-06-11 06:19:01.110  2024-06-11T22:54:38.090Z
# 2024-06-11 06:27:08.787  2024-06-29T05:10:00.040Z
# 2024-06-11 06:36:28.820  2024-06-11T20:02:52.230Z
#
#                                                          place        type  \
# time
# 2024-06-11 06:15:24.120              14 km NE of Milford, Utah  earthquake
# 2024-06-11 06:17:43.805               6 km S of Pýrgos, Greece  earthquake
# 2024-06-11 06:19:01.110  Rat Islands, Aleutian Islands, Alaska  earthquake
# 2024-06-11 06:27:08.787     52 km ESE of Karakenja, Tajikistan  earthquake
# 2024-06-11 06:36:28.820              15 km NE of Milford, Utah  earthquake
#
#                         horizontalError  depthError  magError  magNst  \
# time
# 2024-06-11 06:15:24.120            0.30       0.520  0.527835     3.0
# 2024-06-11 06:17:43.805            5.79       1.869  0.103000    27.0
# 2024-06-11 06:19:01.110            1.10       0.790  0.213680     4.0
# 2024-06-11 06:27:08.787            4.80       1.901  0.185000     8.0
# 2024-06-11 06:36:28.820            0.36       0.540  0.440466     6.0
#
#                            status locationSource magSource
# time
# 2024-06-11 06:15:24.120  reviewed             uu        uu
# 2024-06-11 06:17:43.805  reviewed             us        us
# 2024-06-11 06:19:01.110  reviewed             av        av
# 2024-06-11 06:27:08.787  reviewed             us        us
# 2024-06-11 06:36:28.820  reviewed             uu        uu
#
# [5 rows x 21 columns]

# %%
df["region"] = df.place.str.split(", ", expand=True)[1]
df.region = df.region.fillna(df.place)
df.region = df.region.replace({"CA": "California", "B.C.": "Baja California"})
df = df[['mag', 'depth', 'region']]
df.head()
# Out:
#                           mag  depth            region
# time
# 2024-06-11 06:15:24.120  0.91   3.05              Utah
# 2024-06-11 06:17:43.805  4.40  10.00            Greece
# 2024-06-11 06:19:01.110  0.33   6.32  Aleutian Islands
# 2024-06-11 06:27:08.787  4.10  10.00        Tajikistan
# 2024-06-11 06:36:28.820  0.91   3.01              Utah

# %%
regions = df.region.value_counts()
top_k = 25
top_k_regions = regions.head(top_k).index
df = df.loc[df.region.isin(top_k_regions)]

df = df.groupby("region").resample("d").mean().reset_index()
df.head()
# Out:
#    region       time       mag      depth
# 0  Alaska 2024-06-11  1.094516  29.925161
# 1  Alaska 2024-06-12  0.762857  26.260781
# 2  Alaska 2024-06-13  1.062843  27.405176
# 3  Alaska 2024-06-14  1.188400  31.640227
# 4  Alaska 2024-06-15  1.147250  26.496237

# %%
def reindex(group, delta):
    start_date = group.index.min()
    end_date = pd.Timestamp((datetime.now() + timedelta(days=delta)).date())
    date_range = pd.date_range(start=start_date, end=end_date, freq="d")
    group = group.reindex(date_range)
    group.region = group.region.ffill()
    return group

# %%
df = df.set_index('time')
df = (
    df.groupby("region")[["region", "mag", "depth"]]
    .apply(lambda group: reindex(group, 1), include_groups=False)
    .reset_index(0, drop=True)
)
df.head()
# Out:
#             region       mag      depth
# 2024-06-11  Alaska  1.094516  29.925161
# 2024-06-12  Alaska  0.762857  26.260781
# 2024-06-13  Alaska  1.062843  27.405176
# 2024-06-14  Alaska  1.188400  31.640227
# 2024-06-15  Alaska  1.147250  26.496237

# %%
df[df.region == 'Alaska'].tail()
# Out:
#             region       mag      depth
# 2024-07-08  Alaska  0.956744  23.275558
# 2024-07-09  Alaska  1.051915  25.364255
# 2024-07-10  Alaska  1.102000  18.240700
# 2024-07-11  Alaska  1.808333  35.116667
# 2024-07-12  Alaska       NaN        NaN

# %%
type(df.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df["day"] = df.index.day
df["dayofweek"] = df.index.dayofweek
df["dayofyear"] = df.index.dayofyear

start_lag = 1
end_lag = 7
for i in range(start_lag, end_lag + 1):
    df[f"mag_lag_{i}"] = df.groupby("region").mag.shift(i)

for i in range(start_lag, end_lag + 1):
    df[f"depth_lag_{i}"] = df.groupby("region").depth.shift(i)

df['mag_ewma'] = df.groupby('region')['mag'].transform(lambda x: x.ewm(span=7, adjust=False).mean())
df['depth_ewma'] = df.groupby('region')['depth'].transform(lambda x: x.ewm(span=7, adjust=False).mean())
df.head()
# Out:
#             region       mag      depth  day  dayofweek  dayofyear  mag_lag_1  \
# 2024-06-11  Alaska  1.094516  29.925161   11          1        163        NaN
# 2024-06-12  Alaska  0.762857  26.260781   12          2        164   1.094516
# 2024-06-13  Alaska  1.062843  27.405176   13          3        165   0.762857
# 2024-06-14  Alaska  1.188400  31.640227   14          4        166   1.062843
# 2024-06-15  Alaska  1.147250  26.496237   15          5        167   1.188400
#
#             mag_lag_2  mag_lag_3  mag_lag_4  ...  mag_lag_7  depth_lag_1  \
# 2024-06-11        NaN        NaN        NaN  ...        NaN          NaN
# 2024-06-12        NaN        NaN        NaN  ...        NaN    29.925161
# 2024-06-13   1.094516        NaN        NaN  ...        NaN    26.260781
# 2024-06-14   0.762857   1.094516        NaN  ...        NaN    27.405176
# 2024-06-15   1.062843   0.762857   1.094516  ...        NaN    31.640227
#
#             depth_lag_2  depth_lag_3  depth_lag_4  depth_lag_5  depth_lag_6  \
# 2024-06-11          NaN          NaN          NaN          NaN          NaN
# 2024-06-12          NaN          NaN          NaN          NaN          NaN
# 2024-06-13    29.925161          NaN          NaN          NaN          NaN
# 2024-06-14    26.260781    29.925161          NaN          NaN          NaN
# 2024-06-15    27.405176    26.260781    29.925161          NaN          NaN
#
#             depth_lag_7  mag_ewma  depth_ewma
# 2024-06-11          NaN  1.094516   29.925161
# 2024-06-12          NaN  1.011601   29.009066
# 2024-06-13          NaN  1.024412   28.608094
# 2024-06-14          NaN  1.065409   29.366127
# 2024-06-15          NaN  1.085869   28.648655
#
# [5 rows x 22 columns]

# %%
df = df[df.region == 'Alaska'].fillna(-10.0)

# %%
df[df.region == 'Alaska'].tail()
# Out:
#             region        mag      depth  day  dayofweek  dayofyear  \
# 2024-07-08  Alaska   0.956744  23.275558    8          0        190
# 2024-07-09  Alaska   1.051915  25.364255    9          1        191
# 2024-07-10  Alaska   1.102000  18.240700   10          2        192
# 2024-07-11  Alaska   1.808333  35.116667   11          3        193
# 2024-07-12  Alaska -10.000000 -10.000000   12          4        194
#
#             mag_lag_1  mag_lag_2  mag_lag_3  mag_lag_4  ...  mag_lag_7  \
# 2024-07-08   0.746762   0.685417   1.392245   0.960769  ...   1.210857
# 2024-07-09   0.956744   0.746762   0.685417   1.392245  ...   1.064444
# 2024-07-10   1.051915   0.956744   0.746762   0.685417  ...   0.654948
# 2024-07-11   1.102000   1.051915   0.956744   0.746762  ...   0.960769
# 2024-07-12   1.808333   1.102000   1.051915   0.956744  ...   1.392245
#
#             depth_lag_1  depth_lag_2  depth_lag_3  depth_lag_4  depth_lag_5  \
# 2024-07-08    18.323714    26.125125    26.167347    25.135123    22.162320
# 2024-07-09    23.275558    18.323714    26.125125    26.167347    25.135123
# 2024-07-10    25.364255    23.275558    18.323714    26.125125    26.167347
# 2024-07-11    18.240700    25.364255    23.275558    18.323714    26.125125
# 2024-07-12    35.116667    18.240700    25.364255    23.275558    18.323714
#
#             depth_lag_6  depth_lag_7  mag_ewma  depth_ewma
# 2024-07-08    25.679153    27.306443  0.936022   23.875890
# 2024-07-09    22.162320    25.679153  0.964995   24.247981
# 2024-07-10    25.135123    22.162320  0.999246   22.746161
# 2024-07-11    26.167347    25.135123  1.201518   25.838787
# 2024-07-12    26.125125    26.167347  1.201518   25.838787
#
# [5 rows x 22 columns]

# %%
x = np.array([[1, 2, 3], [4, 5, 6]], np.int32)
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]], dtype=int32)

# %%
column_2 = x[:, 0]
column_2
# Out:
# array([1, 4], dtype=int32)
