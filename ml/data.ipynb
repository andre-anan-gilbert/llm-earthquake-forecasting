# %%
import pandas as pd
import pandas as pd
from datetime import timedelta
from tqdm import tqdm

# %%
start_date = pd.Timestamp('1924-01-01')
end_date = pd.Timestamp('1924-01-31')
date_ranges = [(start_date.date(), end_date.date())]

while end_date < pd.Timestamp('2024-05-31'):
    start_date = end_date + timedelta(days=1)
    end_date = start_date + timedelta(days=10)
    date_ranges.append((start_date.date(), end_date.date()))

if date_ranges[-1][1] > pd.Timestamp('2024-05-31').date():
    date_ranges[-1] = (date_ranges[-1][0], pd.Timestamp('2024-05-31').date())

# %%
df = pd.DataFrame()
for start_time, end_time in tqdm(date_ranges):
    url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&starttime={start_time}&endtime={end_time}&eventtype=earthquake&limit=20000"
    temp_df = pd.read_csv(url)
    df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# 100%|█████████▉| 2291/2292 [1:00:43<00:02,  2.20s/it]/var/folders/_0/wfq3vrsj7pvcsxqlxwqbx6k40000gn/T/ipykernel_31894/841682183.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, temp_df], ignore_index=True)
# 100%|██████████| 2292/2292 [1:00:44<00:00,  1.59s/it]

# %%
df.head()
# Out:
#                        time  latitude  longitude  depth  mag magType  nst  \
# 0  1924-01-30T20:54:44.980Z    19.256    -77.705   35.0  NaN     NaN  NaN
# 1  1924-01-30T04:47:48.940Z    12.313    143.816   35.0  NaN     NaN  NaN
# 2  1924-01-29T01:54:58.960Z   -28.183    -70.715   45.0  6.8      mw  NaN
# 3  1924-01-27T04:22:14.740Z    19.657    121.487   15.0  NaN     NaN  NaN
# 4  1924-01-24T18:34:53.280Z     7.054     94.476   15.0  NaN     NaN  NaN
#
#    gap  dmin  rms  ...                   updated  \
# 0  NaN   NaN  NaN  ...  2022-05-09T17:52:13.342Z
# 1  NaN   NaN  NaN  ...  2022-05-09T17:52:11.629Z
# 2  NaN   NaN  NaN  ...  2022-04-25T23:29:25.973Z
# 3  NaN   NaN  NaN  ...  2022-05-09T17:52:10.074Z
# 4  NaN   NaN  NaN  ...  2022-05-09T17:52:08.503Z
#
#                                place        type horizontalError depthError  \
# 0       84 km N of Falmouth, Jamaica  earthquake             NaN       28.4
# ...

# %%
df.shape
# Out:
# (4145809, 22)

# %%
df.to_csv("earthquakes.csv", index=False)
